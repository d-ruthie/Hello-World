# %%
import numpy as np
import pandas as pd

# %%
FoodBalanceSheet = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin-1')

# %%
FoodBalanceSheet.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
FoodBalanceSheet.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
FoodBalanceSheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
# Area Code       60943 non-null int64
# Area            60943 non-null object
# Item Code       60943 non-null int64
# Item            60943 non-null object
# Element Code    60943 non-null int64
# Element         60943 non-null object
# Unit            60943 non-null object
# Y2014           59354 non-null float64
# Y2015           59395 non-null float64
# Y2016           59408 non-null float64
# Y2017           59437 non-null float64
# Y2018           59507 non-null float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
FoodBalanceSheet.isnull()
# Out:
#        Area Code   Area  Item Code   Item  Element Code  Element   Unit  \
# 0          False  False      False  False         False    False  False
# 1          False  False      False  False         False    False  False
# 2          False  False      False  False         False    False  False
# 3          False  False      False  False         False    False  False
# 4          False  False      False  False         False    False  False
# 5          False  False      False  False         False    False  False
# 6          False  False      False  False         False    False  False
# 7          False  False      False  False         False    False  False
# 8          False  False      False  False         False    False  False
# 9          False  False      False  False         False    False  False
# 10         False  False      False  False         False    False  False
# 11         False  False      False  False         False    False  False
# ...

# %%
df = FoodBalanceSheet.groupby(['Area Code','Area'])

# %%
df.sum()
# Out:
#                                        Item Code  Element Code       Y2014  \
# Area Code Area
# 4         Algeria                        3532053       5017927   313375.33
# 7         Angola                         3819908       5515088   208584.42
# 20        Botswana                       3704902       5259784    22339.92
# 32        Cameroon                       3916078       5663196   217630.28
# 35        Cabo Verde                     3396746       4787751    14576.94
# 37        Central African Republic       3607546       5069094    28739.02
# 39        Chad                           3606529       5108355    65940.17
# 45        Comoros                         124514        241681       32.00
# 46        Congo                          3792029       5445560    38699.26
# 53        Benin                          3453692       4852820   118050.79
# 59        Egypt                          3996567       5893126   849192.30
# ...

# %%
FoodBalanceSheet.corr(method='pearson')
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
FoodBalanceSheet.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
df = FoodBalanceSheet.groupby(['Item'])

# %%
df.sum()
# Out:
#                           Area Code  Item Code  Element Code      Y2014  \
# Item
# Alcohol, Non-Food             38447     752497       1515090    2403.00
# Alcoholic Beverages           75016    1649136       2171381  102410.11
# Animal Products               18060     397035         90990   11935.65
# Animal fats                   85279    1882494       2567303  209460.54
# Apples and products           69280    1352989       1920418    9499.23
# Aquatic Animals, Others       47420     966381       1139179      14.55
# Aquatic Plants                51178    1057275       1278386     507.29
# Aquatic Products, Other       52570    1160712       1320249     519.62
# Bananas                       68496    1338880       1894890   53267.31
# Barley and products           76321    1432410       2243002   25384.66
# Beans                         78001    1476680       2263509   19207.68
# Beer                          65975    1314720       1813728   41879.92
# ...

# %%
df.describe().sum()
# Out:
# Area Code     count     60943.000000
#               mean      16007.347004
#               std        8649.207881
#               min         485.000000
#               25%        8854.250000
#               50%       16236.500000
#               75%       23339.000000
#               max       32819.000000
# Element Code  count     60943.000000
#               mean     447151.088049
#               std      250865.723837
#               min       81105.000000
#               25%      120329.500000
#               50%      596642.000000
#               75%      627919.000000
#               max      686818.000000
# Item Code     count     60943.000000
#               mean     318975.015917
#               std         167.072685
#               min      318808.000000
#               25%      318808.000000
#               50%      318989.500000
#               75%      319142.000000
#               max      319142.000000
# Y2014         count     59354.000000
# ...

# %%
df.sum(Item='all')
# Out:
#                           Area Code  \
# Item
# Alcohol, Non-Food             38447
# Alcoholic Beverages           75016
# Animal Products               18060
# Animal fats                   85279
# Apples and products           69280
# Aquatic Animals, Others       47420
# Aquatic Plants                51178
# Aquatic Products, Other       52570
# Bananas                       68496
# Barley and products           76321
# Beans                         78001
# Beer                          65975
# Beverages, Alcoholic          65918
# Beverages, Fermented          65203
# Bovine Meat                   70033
# Butter, Ghee                  60516
# Cassava and products          73208
# Cephalopods                   58593
# Cereals - Excluding Beer      95370
# Cereals, Other                79505
# Citrus, Other                 70239
# Cloves                        53398
# Cocoa Beans and products      70862
# Coconut Oil                   69418
# Coconuts - Incl Copra         74263
# ...

# %%
FoodBalanceSheet.groupby(['Item'=Y2014,]).sum
# Out:
# <bound method GroupBy.sum of <pandas.core.groupby.DataFrameGroupBy object at 0x000000D1E1A6F128>>

# %%
FoodBalanceSheet.sum()
# Out:
# Area Code                                                 8182547
# Area            AlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlgeriaAlge...
# Item Code                                               163764610
# Item            PopulationPopulationGrand TotalGrand TotalGran...
# Element Code                                            232488797
# Element         Total Population - Both sexesDomestic supply q...
# Unit            1000 persons1000 tonneskcal/capita/dayg/capita...
# Y2014                                                 7.96509e+06
# Y2015                                                 8.03234e+06
# Y2016                                                 8.11247e+06
# Y2017                                                 8.37573e+06
# Y2018                                                 8.55463e+06
# dtype: object

# %%
df2 = FoodBalanceSheet.groupby(['Y2014','Y2017']).sum

# %%
print(df2)
# Out:
# <bound method GroupBy.sum of <pandas.core.groupby.DataFrameGroupBy object at 0x000000D1E1A6B908>>

# %%
FoodBalanceSheet.groupby('Element','Element Code')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-9c6e590374de> in <module>()
# ----> 1 FoodBalanceSheet.groupby('Element','Element Code')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    5157         if level is None and by is None:
#    5158             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 5159         axis = self._get_axis_number(axis)
#    5160         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    5161                        sort=sort, group_keys=group_keys, squeeze=squeeze,
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     355                 pass
#     356         raise ValueError('No axis named {0} for object type {1}'
# ...

# %%
df3.first()
# Out:
#                                         Area Code     Area  Item Code  \
# Element
# Domestic supply quantity                        4  Algeria       2501
# Export Quantity                                 4  Algeria       2905
# Fat supply quantity (g/capita/day)              4  Algeria       2901
# Feed                                            4  Algeria       2905
# Food                                            4  Algeria       2905
# Food supply (kcal/capita/day)                   4  Algeria       2901
# Food supply quantity (kg/capita/yr)             4  Algeria       2905
# Import Quantity                                 4  Algeria       2905
# Losses                                          4  Algeria       2905
# Other uses (non-food)                           4  Algeria       2905
# Processing                                      4  Algeria       2905
# Production                                      4  Algeria       2905
# ...

# %%
E = FoodBalanceSheet.groupby(['Element','Unit'])

# %%
E.first()
# Out:
#                                                         Area Code     Area  \
# Element                                Unit
# Domestic supply quantity               1000 tonnes              4  Algeria
# Export Quantity                        1000 tonnes              4  Algeria
# Fat supply quantity (g/capita/day)     g/capita/day             4  Algeria
# Feed                                   1000 tonnes              4  Algeria
# Food                                   1000 tonnes              4  Algeria
# Food supply (kcal/capita/day)          kcal/capita/day          4  Algeria
# Food supply quantity (kg/capita/yr)    kg                       4  Algeria
# Import Quantity                        1000 tonnes              4  Algeria
# Losses                                 1000 tonnes              4  Algeria
# Other uses (non-food)                  1000 tonnes              4  Algeria
# Processing                             1000 tonnes              4  Algeria
# ...

# %%
FoodBalanceSheet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
# Area Code       60943 non-null int64
# Area            60943 non-null object
# Item Code       60943 non-null int64
# Item            60943 non-null object
# Element Code    60943 non-null int64
# Element         60943 non-null object
# Unit            60943 non-null object
# Y2014           59354 non-null float64
# Y2015           59395 non-null float64
# Y2016           59408 non-null float64
# Y2017           59437 non-null float64
# Y2018           59507 non-null float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB
